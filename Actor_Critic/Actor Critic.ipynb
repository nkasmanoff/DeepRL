# %% [markdown]
# Actor critic methods are a way of reducing the amount of variance from a policy gradient. The idea is that by using two networks, or at least two different function approximators, one can learn two more easily digestible curriculums which can help an agent successfully master whatever environment it is currently in.

# %% [markdown]
# Making a discrete actor critic now.

# %% [markdown]
# To motivate actor critic algorithms mathematically, recall the policy gradient is
#
# $$\nabla_{\theta} J(\theta) = \frac{1}{N} \sum_{i=1}^N \sum_{t=1}^T \nabla_{\theta} log \pi_{\theta}(a_{i,t} | s_{i,t}) G_{i,t}$$
#
# Where $G_{i,t}$ represents some advantage/reward-to-go this policy takes has compared to the other possible actions at that state. In the regular old policy-gradient, $G$ is simply the total remaining rewards to go, implying that this action could either be really good or really bad depending on the value of $G$.
#
# Unfortunately, there are many caveats associated with $G$ simply being the total reward to go. For one, this value is  insensitive to a relative reward difference, meaning that if you were to simply add $40$ to all possible rewards the agent receives, you could end up with a very different policy! Good policies should not be sensitive to scalar shifts. Clearly, we have some work to do...
#
# There are a bunch of ways to fix $G_{i,t}$ for variance reduction, where one of the most popular (and already implemented) was a baseline which corresponded to the mean reward. Additionally, we could see how something like an expected reward to go, would be a better estimate and variance reduction technique. We'll see that shortly.
#
# With a baseline, the policy gradient is
#
# $$\nabla_{\theta} J(\theta) = \frac{1}{N} \sum_{i=1}^N \sum_{t=1}^T \nabla_{\theta} log \pi_{\theta}(a_{i,t} | s_{i,t})( G_{i,t} - b(s_{i,t})$$

# %% [markdown]
# However, there is no reason for this baseline to be a constant number! In fact, it would be a great idea if this baseline could also be a function of the state observation $s_t$. At the same time, this value is starting to look a lot like the reinforcement learning concepts we considered at the beginning of this course, mainly, the $Q$ function, the $V$ function, and the $A$ function.

# %% [markdown]
# The $Q$ value is the expected reward to go, given a state and action.
#
# $Q(s_t,a_t) = E[G_t | (s_t, a_t)]$
#
# The $V$ value is the average $Q$ values in a given state, over possible actions.
#
# $V(s_t) = \sum_a Q(s,a)$
#
# and $A$ represents the advantage a particular $Q$ value has over the average rewards to go in a state. It is simply
#
# $A = Q - V= r + V' - V$
#
# and $V'$ is the value at the next state.
#
# Any three of these functions, (Q,V,A) could be represented as some combination of the other one, and thus could be used as the approximator we plug into the AC algorithm.
#
# In any case we can leverage Bellman optimality conditions, and use that as a method to fit this critic network.
#
# The code for this is below. More specifically, how to make an Actor-Critic Algorithm that trains an actor-critic agent in a continuous action space.
#
# Spoiler alert: This algorithm won't work! But that just gives more motivation to making my own implementation.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import gym 
#from gym import wrappers
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Two networks, with two hidden layers. 

#we'll have an actor network, and a critic network.

class GenericNetwork(nn.Module):
    # To use for both networks 
    def __init__(self,lr,input_dims,fc1_dims,fc2_dims,
                n_actions):
        super(GenericNetwork,self).__init__()
        
        self.lr = lr
        self.input_dims = input_dims
        self.fc1_dims = fc1_dims
        self.fc2_dims = fc2_dims
        self.n_actions = n_actions
    
        self.fc1 = nn.Linear(*self.input_dims, self.fc1_dims)
        self.fc2 = nn.Linear(self.fc1_dims,self.fc2_dims)
        
        self.fc3 = nn.Linear(self.fc2_dims,self.n_actions)
        
        #basis network for both A and C, # of output will change!
        
        self.optimizer = torch.optim.Adam(self.parameters(),lr = self.lr)
        self.device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
    
        self.to(self.device)
    #now the forward pass!
    
    def forward(self,state): 
        #state and obs are interchangeable, not a POMDP setting...
        state = torch.Tensor(state).to(self.device)        
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        x = self.fc3(x) #no activation, handled later 
        return x

# %%
class Agent(object):
    def __init__(self,alpha,beta,input_dims,gamma=0.99, n_actions = 4, 
                layer1_size=64,layer2_size = 64):
        self.gamma = gamma
        self.log_probs = None # log probability of selecting an action 
        self.actor = GenericNetwork(alpha,input_dims,layer1_size,layer2_size,n_actions = n_actions)
        self.critic = GenericNetwork(beta,input_dims,layer1_size,layer2_size,n_actions = 1) 
          
    def choose_action(self,observation):
        probabilities = F.softmax(self.actor.forward(observation))
        # now we need to force these values to make sense, i.e make std real and non-zero. 
        action_probs = torch.distributions.Categorical(probabilities) # probability distribuition dictated by policy network
        #draw sample from it 
        action = action_probs.sample()
        self.log_probs = action_probs.log_prob(action).to(self.actor.device)

        return action.item() #not a tensor!
    
    def learn(self,state,reward,new_state,done):
        #temporal difference style, using state at current and next state.
        #PG doesn't use that, Monte-carlo style, which accumulates rewards over the episode. 
        #This is just a state by state 
        self.actor.optimizer.zero_grad()
        self.critic.optimizer.zero_grad()
        
        critic_value_ = self.critic.forward(new_state) #Q value of next state for TD critic loss
        critic_value = self.critic.forward(state) #Q val at current state
        
        reward = torch.Tensor([reward]).to(self.actor.device)
        
        delta = reward + self.gamma* critic_value_*(1-int(done))  - critic_value#loss! but also the Advantage? # Q - V = A and this is the same thing as V - y, just re-ordered. In any case use for both. 
            #y_i - Vphi i , and this is the same as advantage
        
        actor_loss = -self.log_probs * delta
        
        critic_loss = delta **2  #minimize 
        
        #now sum the two, and backpropagate
        
        (actor_loss + critic_loss).backward() #can't do two backward passes at once, but these losses
        #are inpdt so it will update separately :) 
        self.actor.optimizer.step()
        self.critic.optimizer.step()

# %%
# now the main

agent = Agent(alpha = 0.001, beta = .001, input_dims = [4], gamma=0.99,
             layer1_size = 64, layer2_size=64,n_actions=2)

env = gym.make('CartPole-v1')
score_history = []
num_episodes = 2000
for i in range(num_episodes):
    done = False
    score = 0
    observation = env.reset()
    #now the game!
    
    while not done:
        action = agent.choose_action(observation)
        env.render()
        observation_,reward, done, _ = env.step(action)
  #      agent.learn(observation,reward,observation_, done)
        
        observation = observation_        
        score += reward
    score_history.append(score)
    
    print("Episode ", i, 'score ', score)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Episode  0 score  9.0
# Episode  1 score  17.0
# Episode  2 score  14.0
# Episode  3 score  37.0
# Episode  4 score  40.0
# /Users/noahkasmanoff/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   # Remove the CWD from sys.path while we load stuff.
# Episode  5 score  18.0
# Episode  6 score  46.0
# Episode  7 score  33.0
# Episode  8 score  12.0
# Episode  9 score  28.0
# Episode  10 score  9.0
# Episode  11 score  74.0
# Episode  12 score  15.0
# Episode  13 score  13.0
# Episode  14 score  9.0
# Episode  15 score  29.0
# Episode  16 score  12.0
# Episode  17 score  32.0
# Episode  18 score  22.0
# Episode  19 score  14.0
# Episode  20 score  14.0
# Episode  21 score  11.0
# Episode  22 score  17.0
# Episode  23 score  13.0
# Episode  24 score  38.0
# Episode  25 score  14.0
# Episode  26 score  20.0
# Episode  27 score  16.0
# Episode  28 score  12.0
# Episode  29 score  22.0
# Episode  30 score  15.0
# Episode  31 score  26.0
# Episode  32 score  19.0
# Episode  33 score  13.0
# Episode  34 score  18.0
# Episode  35 score  16.0
# Episode  36 score  11.0
# Episode  37 score  25.0
# Episode  38 score  14.0
# Episode  39 score  30.0
# Episode  40 score  19.0
# Episode  41 score  10.0
# Episode  42 score  12.0
# Episode  43 score  12.0
# Episode  44 score  9.0
# Episode  45 score  11.0
# Episode  46 score  21.0
# Episode  47 score  16.0
# Episode  48 score  14.0
# Episode  49 score  13.0
# Episode  50 score  19.0
# Episode  51 score  29.0
# Episode  52 score  18.0
# Episode  53 score  13.0
# Episode  54 score  34.0
# Episode  55 score  9.0
# Episode  56 score  16.0
# Episode  57 score  15.0
# Episode  58 score  20.0
# Episode  59 score  31.0
# Episode  60 score  17.0
# Episode  61 score  21.0
# Episode  62 score  11.0
# Episode  63 score  16.0
# Episode  64 score  15.0
# Episode  65 score  13.0
# Episode  66 score  17.0
# Episode  67 score  15.0
# Episode  68 score  17.0
# Episode  69 score  14.0
# Episode  70 score  9.0
# Episode  71 score  44.0
# Episode  72 score  16.0
# Episode  73 score  12.0
# Episode  74 score  46.0
# Episode  75 score  17.0
# Episode  76 score  9.0
# Episode  77 score  29.0
# Episode  78 score  10.0
# Episode  79 score  11.0
# Episode  80 score  32.0
# Episode  81 score  12.0
# Episode  82 score  13.0
# Episode  83 score  52.0
# Episode  84 score  39.0
# Episode  85 score  38.0
# Episode  86 score  26.0
# Episode  87 score  36.0
# Episode  88 score  34.0
# Episode  89 score  24.0
# Episode  90 score  12.0
# Episode  91 score  17.0
# Episode  92 score  15.0
# Episode  93 score  19.0
# Episode  94 score  41.0
# Episode  95 score  21.0
# Episode  96 score  11.0
# Episode  97 score  10.0
# Episode  98 score  14.0
# Episode  99 score  29.0
# Episode  100 score  40.0
# Episode  101 score  11.0
# Episode  102 score  22.0
# Episode  103 score  17.0
# Episode  104 score  16.0
# Episode  105 score  13.0
# Episode  106 score  17.0
# Episode  107 score  20.0
# Episode  108 score  14.0
# Episode  109 score  33.0
# Episode  110 score  32.0
# Episode  111 score  15.0
# Episode  112 score  15.0
# Episode  113 score  26.0
# Episode  114 score  17.0
# Episode  115 score  14.0
# Episode  116 score  12.0
# Episode  117 score  14.0
# Episode  118 score  9.0
# Episode  119 score  16.0
# Episode  120 score  14.0
# Episode  121 score  19.0
# Episode  122 score  37.0
# Episode  123 score  12.0
# Episode  124 score  11.0
# Episode  125 score  14.0
# Episode  126 score  47.0
# Episode  127 score  21.0
# Episode  128 score  27.0
# Episode  129 score  24.0
# Episode  130 score  25.0
# Episode  131 score  25.0
# Episode  132 score  14.0
# Episode  133 score  25.0
# Episode  134 score  14.0
# Episode  135 score  19.0
# Episode  136 score  26.0
# Episode  137 score  17.0
# Episode  138 score  28.0
# Episode  139 score  34.0
# Episode  140 score  21.0
# Episode  141 score  9.0
# Episode  142 score  28.0
# Episode  143 score  12.0
# Episode  144 score  12.0
# Episode  145 score  10.0
# Episode  146 score  21.0
# Episode  147 score  10.0
# Episode  148 score  16.0
# Episode  149 score  64.0
# Episode  150 score  22.0
# Episode  151 score  29.0
# Episode  152 score  16.0
# Episode  153 score  23.0
# Episode  154 score  12.0
# Episode  155 score  13.0
# Episode  156 score  58.0
# Episode  157 score  43.0
# Episode  158 score  27.0
# Episode  159 score  11.0
# Episode  160 score  40.0
# Episode  161 score  12.0
# Episode  162 score  11.0
# Episode  163 score  14.0
# Episode  164 score  33.0
# Episode  165 score  29.0
# Episode  166 score  31.0
# Episode  167 score  14.0
# Episode  168 score  12.0
# Episode  169 score  41.0
# Episode  170 score  16.0
# Episode  171 score  10.0
# Episode  172 score  15.0
# Episode  173 score  30.0
# Episode  174 score  23.0
# Episode  175 score  14.0
# Episode  176 score  14.0
# Episode  177 score  9.0
# Episode  178 score  45.0
# Episode  179 score  29.0
# Episode  180 score  35.0
# Episode  181 score  26.0
# Episode  182 score  16.0
# Episode  183 score  18.0
# Episode  184 score  14.0
# Episode  185 score  16.0
# Episode  186 score  11.0
# Episode  187 score  12.0
# Episode  188 score  10.0
# Episode  189 score  19.0
# Episode  190 score  21.0
# Episode  191 score  11.0
# Episode  192 score  33.0
# Episode  193 score  15.0
# Episode  194 score  14.0
# Episode  195 score  25.0
# Episode  196 score  11.0
# Episode  197 score  44.0
# Episode  198 score  13.0
# Episode  199 score  28.0
# Episode  200 score  14.0
# Episode  201 score  20.0
# Episode  202 score  18.0
# Episode  203 score  15.0
# Episode  204 score  30.0
# Episode  205 score  26.0
# Episode  206 score  30.0
# Episode  207 score  14.0
# Episode  208 score  14.0
# Episode  209 score  12.0
# Episode  210 score  29.0
# Episode  211 score  67.0
# Episode  212 score  17.0
# Episode  213 score  15.0
# Episode  214 score  13.0
# Episode  215 score  16.0
# Episode  216 score  11.0
# Episode  217 score  12.0
# Episode  218 score  16.0
# Episode  219 score  12.0
# Episode  220 score  22.0
# Episode  221 score  13.0
# Episode  222 score  24.0
# Episode  223 score  22.0
# Episode  224 score  14.0
# Episode  225 score  34.0
# Episode  226 score  33.0
# Episode  227 score  26.0
# Episode  228 score  12.0
# Episode  229 score  30.0
# Episode  230 score  18.0
# Episode  231 score  15.0
# Episode  232 score  20.0
# Episode  233 score  31.0
# Episode  234 score  11.0
# Episode  235 score  10.0
# Episode  236 score  15.0
# Episode  237 score  14.0
# Episode  238 score  16.0
# Episode  239 score  17.0
# Episode  240 score  16.0
# Episode  241 score  31.0
# Episode  242 score  10.0
# Episode  243 score  11.0
# Episode  244 score  34.0
# Episode  245 score  15.0
# Episode  246 score  13.0
# Episode  247 score  74.0
# Episode  248 score  33.0
# Episode  249 score  11.0
# Episode  250 score  12.0
# Episode  251 score  27.0
# Episode  252 score  36.0
# Episode  253 score  14.0
# Episode  254 score  16.0
# Episode  255 score  14.0
# Episode  256 score  20.0
# Episode  257 score  12.0
# Episode  258 score  10.0
# Episode  259 score  30.0
# Episode  260 score  19.0
# Episode  261 score  20.0
# Episode  262 score  11.0
# Episode  263 score  27.0
# Episode  264 score  12.0
# Episode  265 score  58.0
# Episode  266 score  33.0
# Episode  267 score  20.0
# Episode  268 score  13.0
# Episode  269 score  13.0
# Episode  270 score  35.0
# Episode  271 score  20.0
# Episode  272 score  12.0
# Episode  273 score  13.0
# Episode  274 score  10.0
# Episode  275 score  46.0
# Episode  276 score  12.0
# Episode  277 score  15.0
# Episode  278 score  16.0
# Episode  279 score  32.0
# Episode  280 score  23.0
# Episode  281 score  23.0
# Episode  282 score  40.0
# Episode  283 score  21.0
# Episode  284 score  20.0
# Episode  285 score  15.0
# Episode  286 score  14.0
# Episode  287 score  11.0
# Episode  288 score  14.0
# Episode  289 score  30.0
# Episode  290 score  15.0
# Episode  291 score  22.0
# Episode  292 score  22.0
# Episode  293 score  17.0
# Episode  294 score  35.0
# Episode  295 score  15.0
# Episode  296 score  25.0
# Episode  297 score  21.0
# Episode  298 score  22.0
# Episode  299 score  62.0
# Episode  300 score  34.0
# Episode  301 score  41.0
# Episode  302 score  15.0
# Episode  303 score  23.0
# Episode  304 score  20.0
# Episode  305 score  26.0
# Episode  306 score  40.0
# Episode  307 score  11.0
# Episode  308 score  13.0
# Episode  309 score  29.0
# Episode  310 score  28.0
# Episode  311 score  15.0
# Episode  312 score  9.0
# Episode  313 score  14.0
# Episode  314 score  21.0
# Episode  315 score  12.0
# Episode  316 score  15.0
# Episode  317 score  31.0
# Episode  318 score  11.0
# Episode  319 score  16.0
# Episode  320 score  23.0
# Episode  321 score  19.0
# Episode  322 score  11.0
# Episode  323 score  13.0
# Episode  324 score  10.0
# Episode  325 score  13.0
# Episode  326 score  23.0
# Episode  327 score  13.0
# Episode  328 score  20.0
# Episode  329 score  15.0
# Episode  330 score  10.0
# Episode  331 score  9.0
# Episode  332 score  20.0
# Episode  333 score  27.0
# Episode  334 score  11.0
# Episode  335 score  13.0
# Episode  336 score  15.0
# Episode  337 score  18.0
# Episode  338 score  31.0
# Episode  339 score  11.0
# Episode  340 score  51.0
# Episode  341 score  25.0
# Episode  342 score  19.0
# Episode  343 score  39.0
# Episode  344 score  15.0
# Episode  345 score  24.0
# Episode  346 score  12.0
# Episode  347 score  26.0
# Episode  348 score  11.0
# Episode  349 score  10.0
# Episode  350 score  17.0
# Episode  351 score  41.0
# Episode  352 score  34.0
# Episode  353 score  16.0
# Episode  354 score  26.0
# Episode  355 score  73.0
# Episode  356 score  10.0
# Episode  357 score  20.0
# Episode  358 score  15.0
# Episode  359 score  18.0
# Episode  360 score  11.0
# Episode  361 score  20.0
# Episode  362 score  69.0
# Episode  363 score  13.0
# Episode  364 score  19.0
# Episode  365 score  17.0
# Episode  366 score  11.0
# Episode  367 score  16.0
# Episode  368 score  54.0
# Episode  369 score  19.0
# Episode  370 score  31.0
# Episode  371 score  25.0
# Episode  372 score  12.0
# Episode  373 score  13.0
# Episode  374 score  17.0
# Episode  375 score  14.0
# Episode  376 score  11.0
# Episode  377 score  28.0
# Episode  378 score  30.0
# Episode  379 score  14.0
# Episode  380 score  11.0
# Episode  381 score  14.0
# Episode  382 score  37.0
# Episode  383 score  36.0
# Episode  384 score  13.0
# Episode  385 score  11.0
# Episode  386 score  22.0
# Episode  387 score  8.0
# Episode  388 score  17.0
# Episode  389 score  12.0
# Episode  390 score  10.0
# Episode  391 score  16.0
# Episode  392 score  17.0
# Episode  393 score  9.0
# Episode  394 score  19.0
# Episode  395 score  18.0
# Episode  396 score  17.0
# Episode  397 score  15.0
# Episode  398 score  13.0
# Episode  399 score  22.0
# Episode  400 score  13.0
# Episode  401 score  16.0
# Episode  402 score  18.0
# Episode  403 score  12.0
# Episode  404 score  30.0
# Episode  405 score  14.0
# Episode  406 score  13.0
# Episode  407 score  28.0
# Episode  408 score  16.0
# Episode  409 score  21.0
# Episode  410 score  12.0
# Episode  411 score  71.0
# Episode  412 score  14.0
# Episode  413 score  18.0
# Episode  414 score  15.0
# Episode  415 score  49.0
# Episode  416 score  22.0
# Episode  417 score  21.0
# Episode  418 score  14.0
# Episode  419 score  22.0
# Episode  420 score  25.0
# Episode  421 score  15.0
# Episode  422 score  43.0
# Episode  423 score  18.0
# Episode  424 score  18.0
# Episode  425 score  17.0
# Episode  426 score  23.0
# Episode  427 score  12.0
# Episode  428 score  13.0
# Episode  429 score  18.0
# Episode  430 score  19.0
# Episode  431 score  10.0
# Episode  432 score  17.0
# Episode  433 score  16.0
# Episode  434 score  23.0
# Episode  435 score  18.0
# Episode  436 score  18.0
# Episode  437 score  11.0
# Episode  438 score  35.0
# Episode  439 score  23.0
# Episode  440 score  19.0
# Episode  441 score  11.0
# Episode  442 score  31.0
# Episode  443 score  17.0
# Episode  444 score  30.0
# Episode  445 score  30.0
# Episode  446 score  16.0
# Episode  447 score  16.0
# Episode  448 score  23.0
# Episode  449 score  30.0
# Episode  450 score  10.0
# Episode  451 score  24.0
# Episode  452 score  13.0
# Episode  453 score  11.0
# Episode  454 score  14.0
# Episode  455 score  27.0
# Episode  456 score  12.0
# Episode  457 score  18.0
# Episode  458 score  19.0
# Episode  459 score  17.0
# Episode  460 score  12.0
# Episode  461 score  18.0
# Episode  462 score  12.0
# Episode  463 score  13.0
# Episode  464 score  17.0
# Episode  465 score  15.0
# Episode  466 score  11.0
# Episode  467 score  43.0
# Episode  468 score  22.0
# Episode  469 score  10.0
# Episode  470 score  24.0
# Episode  471 score  32.0
# Episode  472 score  39.0
# Episode  473 score  43.0
# Episode  474 score  38.0
# Episode  475 score  11.0
# Episode  476 score  23.0
# Episode  477 score  39.0
# Episode  478 score  28.0
# Episode  479 score  19.0
# Episode  480 score  28.0
# Episode  481 score  16.0
# Episode  482 score  16.0
# Episode  483 score  12.0
# Episode  484 score  19.0
# Episode  485 score  15.0
# Episode  486 score  34.0
# Episode  487 score  9.0
# Episode  488 score  41.0
# Episode  489 score  10.0
# Episode  490 score  18.0
# Episode  491 score  23.0
# Episode  492 score  29.0
# Episode  493 score  14.0
# Episode  494 score  38.0
# Episode  495 score  10.0
# Episode  496 score  10.0
# Episode  497 score  18.0
# Episode  498 score  13.0
# Episode  499 score  12.0
# Episode  500 score  29.0
# Episode  501 score  21.0
# Episode  502 score  31.0
# Episode  503 score  14.0
# Episode  504 score  14.0
# Episode  505 score  28.0
# Episode  506 score  24.0
# Episode  507 score  20.0
# Episode  508 score  13.0
# Episode  509 score  16.0
# Episode  510 score  20.0
# Episode  511 score  36.0
# Episode  512 score  57.0
# Episode  513 score  13.0
# Episode  514 score  14.0
# Episode  515 score  16.0
# Episode  516 score  13.0
# Episode  517 score  15.0
# Episode  518 score  24.0
# Episode  519 score  15.0
# Episode  520 score  17.0
# Episode  521 score  29.0
# Episode  522 score  17.0
# Episode  523 score  19.0
# Episode  524 score  10.0
# Episode  525 score  11.0
# Episode  526 score  26.0
# Episode  527 score  14.0
# Episode  528 score  31.0
# Episode  529 score  39.0
# Episode  530 score  40.0
# Episode  531 score  25.0
# Episode  532 score  46.0
# Episode  533 score  16.0
# Episode  534 score  39.0
# Episode  535 score  24.0
# Episode  536 score  12.0
# Episode  537 score  11.0
# Episode  538 score  15.0
# Episode  539 score  17.0
# Episode  540 score  26.0
# Episode  541 score  13.0
# Episode  542 score  16.0
# Episode  543 score  15.0
# Episode  544 score  63.0
# Episode  545 score  12.0
# Episode  546 score  13.0
# Episode  547 score  35.0
# Episode  548 score  19.0
# Episode  549 score  23.0
# Episode  550 score  12.0
# Episode  551 score  12.0
# Episode  552 score  20.0
# Episode  553 score  14.0
# Episode  554 score  12.0
# Episode  555 score  19.0
# Episode  556 score  23.0
# Episode  557 score  35.0
# Episode  558 score  20.0
# Episode  559 score  25.0
# Episode  560 score  13.0
# Episode  561 score  9.0
# Episode  562 score  27.0
# Episode  563 score  11.0
# Episode  564 score  15.0
# Episode  565 score  12.0
# Episode  566 score  26.0
# Episode  567 score  31.0
# Episode  568 score  15.0
# Episode  569 score  23.0
# Episode  570 score  11.0
# Episode  571 score  10.0
# Episode  572 score  21.0
# Episode  573 score  14.0
# Episode  574 score  48.0
# Episode  575 score  25.0
# Episode  576 score  11.0
# Episode  577 score  24.0
# Episode  578 score  13.0
# Episode  579 score  15.0
# Episode  580 score  14.0
# Episode  581 score  20.0
# Episode  582 score  15.0
# Episode  583 score  23.0
# Episode  584 score  12.0
# Episode  585 score  10.0
# Episode  586 score  12.0
# Episode  587 score  16.0
# Episode  588 score  12.0
# Episode  589 score  18.0
# Episode  590 score  20.0
# Episode  591 score  19.0
# Episode  592 score  12.0
# Episode  593 score  22.0
# Episode  594 score  15.0
# Episode  595 score  33.0
# Episode  596 score  13.0
# Episode  597 score  11.0
# Episode  598 score  43.0
# Episode  599 score  16.0
# Episode  600 score  20.0
# Episode  601 score  21.0
# Episode  602 score  26.0
# Episode  603 score  45.0
# Episode  604 score  18.0
# Episode  605 score  24.0
# Episode  606 score  14.0
# Episode  607 score  15.0
# Episode  608 score  17.0
# Episode  609 score  15.0
# Episode  610 score  9.0
# Episode  611 score  16.0
# Episode  612 score  19.0
# Episode  613 score  12.0
# Episode  614 score  19.0
# Episode  615 score  14.0
# Episode  616 score  18.0
# Episode  617 score  13.0
# Episode  618 score  35.0
# Episode  619 score  20.0
# Episode  620 score  13.0
# Episode  621 score  16.0
# Episode  622 score  9.0
# Episode  623 score  16.0
# Episode  624 score  15.0
# Episode  625 score  35.0
# Episode  626 score  19.0
# Episode  627 score  15.0
# Episode  628 score  35.0
# Episode  629 score  19.0
# Episode  630 score  14.0
# Episode  631 score  16.0
# Episode  632 score  15.0
# Episode  633 score  15.0
# Episode  634 score  19.0
# Episode  635 score  20.0
# Episode  636 score  14.0
# Episode  637 score  12.0
# Episode  638 score  23.0
# Episode  639 score  29.0
# Episode  640 score  10.0
# Episode  641 score  17.0
# Episode  642 score  28.0
# Episode  643 score  21.0
# Episode  644 score  27.0
# Episode  645 score  14.0
# Episode  646 score  27.0
# Episode  647 score  13.0
# Episode  648 score  13.0
# Episode  649 score  26.0
# Episode  650 score  22.0
# Episode  651 score  15.0
# Episode  652 score  10.0
# Episode  653 score  32.0
# Episode  654 score  12.0
# Episode  655 score  16.0
# Episode  656 score  14.0
# Episode  657 score  8.0
# Episode  658 score  35.0
# Episode  659 score  19.0
# Episode  660 score  9.0
# Episode  661 score  23.0
# Episode  662 score  31.0
# Episode  663 score  43.0
# Episode  664 score  24.0
# Episode  665 score  39.0
# Episode  666 score  8.0
# Episode  667 score  29.0
# Episode  668 score  18.0
# Episode  669 score  23.0
# Episode  670 score  16.0
# Episode  671 score  12.0
# Episode  672 score  16.0
# Episode  673 score  13.0
# Episode  674 score  36.0
# Episode  675 score  12.0
# Episode  676 score  10.0
# Episode  677 score  14.0
# Episode  678 score  29.0
# Episode  679 score  13.0
# Episode  680 score  40.0
# Episode  681 score  20.0
# Episode  682 score  42.0
# Episode  683 score  14.0
# Episode  684 score  16.0
# Episode  685 score  15.0
# Episode  686 score  34.0
# Episode  687 score  33.0
# Episode  688 score  11.0
# Episode  689 score  14.0
# Episode  690 score  14.0
# Episode  691 score  14.0
# Episode  692 score  18.0
# Episode  693 score  18.0
# Episode  694 score  66.0
# Episode  695 score  17.0
# Episode  696 score  13.0
# Episode  697 score  22.0
# Episode  698 score  15.0
# Episode  699 score  20.0
# Episode  700 score  13.0
# Episode  701 score  19.0
# Episode  702 score  17.0
# Episode  703 score  11.0
# Episode  704 score  17.0
# Episode  705 score  34.0
# Episode  706 score  11.0
# Episode  707 score  15.0
# Episode  708 score  19.0
# Episode  709 score  19.0
# Episode  710 score  20.0
# Episode  711 score  39.0
# Episode  712 score  15.0
# Episode  713 score  18.0
# Episode  714 score  12.0
# Episode  715 score  13.0
# Episode  716 score  16.0
# Episode  717 score  23.0
# Episode  718 score  15.0
# Episode  719 score  24.0
# Episode  720 score  21.0
# Episode  721 score  10.0
# Episode  722 score  16.0
# Episode  723 score  55.0
# Episode  724 score  10.0
# Episode  725 score  30.0
# Episode  726 score  23.0
# Episode  727 score  19.0
# Episode  728 score  29.0
# Episode  729 score  51.0
# Episode  730 score  36.0
# Episode  731 score  12.0
# Episode  732 score  18.0
# Episode  733 score  15.0
# Episode  734 score  14.0
# Episode  735 score  29.0
# Episode  736 score  33.0
# Episode  737 score  38.0
# Episode  738 score  12.0
# Episode  739 score  10.0
# Episode  740 score  17.0
# Episode  741 score  46.0
# Episode  742 score  11.0
# Episode  743 score  30.0
# Episode  744 score  16.0
# Episode  745 score  33.0
# Episode  746 score  16.0
# Episode  747 score  36.0
# Episode  748 score  12.0
# Episode  749 score  41.0
# Episode  750 score  54.0
# Episode  751 score  35.0
# Episode  752 score  17.0
# Episode  753 score  17.0
# Episode  754 score  16.0
# Episode  755 score  12.0
# Episode  756 score  22.0
# Episode  757 score  9.0
# Episode  758 score  22.0
# Episode  759 score  25.0
# Episode  760 score  13.0
# Episode  761 score  12.0
# Episode  762 score  33.0
# Episode  763 score  14.0
# Episode  764 score  25.0
# Episode  765 score  10.0
# Episode  766 score  12.0
# Episode  767 score  31.0
# Episode  768 score  20.0
# Episode  769 score  12.0
# Episode  770 score  23.0
# Episode  771 score  12.0
# Episode  772 score  15.0
# Episode  773 score  24.0
# Episode  774 score  33.0
# Episode  775 score  26.0
# Episode  776 score  10.0
# Episode  777 score  33.0
# Episode  778 score  31.0
# Episode  779 score  21.0
# Episode  780 score  47.0
# Episode  781 score  39.0
# Episode  782 score  13.0
# Episode  783 score  16.0
# Episode  784 score  15.0
# Episode  785 score  11.0
# Episode  786 score  28.0
# Episode  787 score  22.0
# Episode  788 score  14.0
# Episode  789 score  43.0
# Episode  790 score  13.0
# Episode  791 score  13.0
# Episode  792 score  16.0
# Episode  793 score  22.0
# Episode  794 score  31.0
# Episode  795 score  19.0
# Episode  796 score  51.0
# Episode  797 score  13.0
# Episode  798 score  13.0
# Episode  799 score  22.0
# Episode  800 score  23.0
# Episode  801 score  25.0
# Episode  802 score  20.0
# Episode  803 score  21.0
# Episode  804 score  54.0
# Episode  805 score  11.0
# Episode  806 score  11.0
# Episode  807 score  18.0
# Episode  808 score  14.0
# Episode  809 score  14.0
# Episode  810 score  12.0
# Episode  811 score  22.0
# Episode  812 score  16.0
# Episode  813 score  15.0
# Episode  814 score  14.0
# Episode  815 score  15.0
# Episode  816 score  26.0
# Episode  817 score  23.0
# Episode  818 score  35.0
# Episode  819 score  32.0
# Episode  820 score  37.0
# Episode  821 score  9.0
# Episode  822 score  30.0
# Episode  823 score  22.0
# Episode  824 score  16.0
# Episode  825 score  30.0
# Episode  826 score  24.0
# Episode  827 score  23.0
# Episode  828 score  14.0
# Episode  829 score  23.0
# Episode  830 score  12.0
# Episode  831 score  21.0
# Episode  832 score  17.0
# Episode  833 score  43.0
# Episode  834 score  16.0
# Episode  835 score  13.0
# Episode  836 score  12.0
# Episode  837 score  8.0
# Episode  838 score  19.0
# Episode  839 score  22.0
# Episode  840 score  18.0
# Episode  841 score  17.0
# Episode  842 score  25.0
# Episode  843 score  25.0
# Episode  844 score  30.0
# Episode  845 score  16.0
# Episode  846 score  37.0
# Episode  847 score  23.0
# Episode  848 score  15.0
# Episode  849 score  9.0
# Episode  850 score  18.0
# Episode  851 score  17.0
# Episode  852 score  38.0
# Episode  853 score  16.0
# Episode  854 score  26.0
# Episode  855 score  49.0
# Episode  856 score  19.0
# Episode  857 score  28.0
# Episode  858 score  24.0
# Episode  859 score  14.0
# Episode  860 score  22.0
# Episode  861 score  13.0
# Episode  862 score  21.0
# Episode  863 score  35.0
# Episode  864 score  12.0
# Episode  865 score  15.0
# Episode  866 score  10.0
# Episode  867 score  28.0
# Episode  868 score  22.0
# Episode  869 score  11.0
# Episode  870 score  16.0
# Episode  871 score  24.0
# Episode  872 score  11.0
# Episode  873 score  15.0
# Episode  874 score  41.0
# Episode  875 score  22.0
# Episode  876 score  28.0
# Episode  877 score  25.0
# Episode  878 score  19.0
# Episode  879 score  20.0
# Episode  880 score  51.0
# Episode  881 score  11.0
# Episode  882 score  68.0
# Episode  883 score  22.0
# Episode  884 score  25.0
# Episode  885 score  12.0
# Episode  886 score  17.0
# Episode  887 score  19.0
# Episode  888 score  15.0
# Episode  889 score  13.0
# Episode  890 score  20.0
# Episode  891 score  12.0
# Episode  892 score  27.0
# Episode  893 score  15.0
# Episode  894 score  10.0
# Episode  895 score  37.0
# Episode  896 score  13.0
# Episode  897 score  13.0
# Episode  898 score  13.0
# Episode  899 score  25.0
# Episode  900 score  15.0
# Episode  901 score  15.0
# Episode  902 score  14.0
# Episode  903 score  12.0
# Episode  904 score  9.0
# Episode  905 score  29.0
# Episode  906 score  16.0
# Episode  907 score  10.0
# Episode  908 score  13.0
# Episode  909 score  11.0
# Episode  910 score  31.0
# Episode  911 score  16.0
# Episode  912 score  14.0
# Episode  913 score  50.0
# Episode  914 score  9.0
# Episode  915 score  10.0
# Episode  916 score  10.0
# Episode  917 score  18.0
# Episode  918 score  44.0
# Episode  919 score  22.0
# Episode  920 score  38.0
# Episode  921 score  39.0
# Episode  922 score  14.0
# Episode  923 score  11.0
# Episode  924 score  12.0
# Episode  925 score  20.0
# Episode  926 score  13.0
# Episode  927 score  23.0
# Episode  928 score  10.0
# Episode  929 score  24.0
# Episode  930 score  14.0
# Episode  931 score  29.0
# Episode  932 score  12.0
# Episode  933 score  10.0
# Episode  934 score  25.0
# Episode  935 score  62.0
# Episode  936 score  29.0
# Episode  937 score  14.0
# Episode  938 score  26.0
# Episode  939 score  13.0
# Episode  940 score  26.0
# Episode  941 score  15.0
# Episode  942 score  15.0
# Episode  943 score  11.0
# Episode  944 score  16.0
# Episode  945 score  12.0
# Episode  946 score  30.0
# Episode  947 score  14.0
# Episode  948 score  27.0
# Episode  949 score  13.0
# Episode  950 score  14.0
# Episode  951 score  15.0
# Episode  952 score  14.0
# Episode  953 score  14.0
# Episode  954 score  22.0
# Episode  955 score  48.0
# Episode  956 score  13.0
# Episode  957 score  11.0
# Episode  958 score  12.0
# Episode  959 score  18.0
# Episode  960 score  38.0
# Episode  961 score  11.0
# Episode  962 score  31.0
# Episode  963 score  25.0
# Episode  964 score  38.0
# Episode  965 score  14.0
# Episode  966 score  17.0
# Episode  967 score  16.0
# Episode  968 score  30.0
# Episode  969 score  15.0
# Episode  970 score  20.0
# Episode  971 score  24.0
# Episode  972 score  11.0
# Episode  973 score  31.0
# Episode  974 score  12.0
# Episode  975 score  11.0
# Episode  976 score  18.0
# Episode  977 score  33.0
# Episode  978 score  26.0
# Episode  979 score  41.0
# Episode  980 score  25.0
# Episode  981 score  10.0
# Episode  982 score  16.0
# Episode  983 score  25.0
# Episode  984 score  26.0
# Episode  985 score  13.0
# Episode  986 score  16.0
# Episode  987 score  18.0
# Episode  988 score  14.0
# Episode  989 score  20.0
# Episode  990 score  20.0
# Episode  991 score  26.0
# Episode  992 score  24.0
# Episode  993 score  30.0
# Episode  994 score  16.0
# Episode  995 score  16.0
# Episode  996 score  10.0
# Episode  997 score  16.0
# Episode  998 score  15.0
# Episode  999 score  32.0
# Episode  1000 score  17.0
# Episode  1001 score  21.0
# Episode  1002 score  32.0
# Episode  1003 score  18.0
# Episode  1004 score  29.0
# Episode  1005 score  12.0
# Episode  1006 score  15.0
# Episode  1007 score  14.0
# Episode  1008 score  10.0
# Episode  1009 score  17.0
# Episode  1010 score  23.0
# Episode  1011 score  19.0
# Episode  1012 score  20.0
# Episode  1013 score  12.0
# Episode  1014 score  17.0
# Episode  1015 score  16.0
# Episode  1016 score  20.0
# Episode  1017 score  20.0
# Episode  1018 score  13.0
# Episode  1019 score  11.0
# Episode  1020 score  13.0
# Episode  1021 score  22.0
# Episode  1022 score  15.0
# Episode  1023 score  24.0
# Episode  1024 score  22.0
# Episode  1025 score  12.0
# Episode  1026 score  22.0
# Episode  1027 score  13.0
# Episode  1028 score  11.0
# Episode  1029 score  28.0
# Episode  1030 score  43.0
# Episode  1031 score  15.0
# Episode  1032 score  56.0
# Episode  1033 score  14.0
# Episode  1034 score  39.0
# Episode  1035 score  14.0
# Episode  1036 score  22.0
# Episode  1037 score  10.0
# Episode  1038 score  13.0
# Episode  1039 score  13.0
# Episode  1040 score  22.0
# Episode  1041 score  9.0
# Episode  1042 score  14.0
# Episode  1043 score  10.0
# Episode  1044 score  23.0
# Episode  1045 score  10.0
# Episode  1046 score  13.0
# Episode  1047 score  36.0
# Episode  1048 score  11.0
# Episode  1049 score  10.0
# Episode  1050 score  11.0
# Episode  1051 score  22.0
# Episode  1052 score  15.0
# Episode  1053 score  11.0
# Episode  1054 score  14.0
# Episode  1055 score  13.0
# Episode  1056 score  23.0
# Episode  1057 score  11.0
# Episode  1058 score  16.0
# Episode  1059 score  13.0
# Episode  1060 score  10.0
# Episode  1061 score  12.0
# Episode  1062 score  23.0
# Episode  1063 score  24.0
# Episode  1064 score  48.0
# Episode  1065 score  16.0
# Episode  1066 score  10.0
# Episode  1067 score  10.0
# Episode  1068 score  13.0
# Episode  1069 score  38.0
# Episode  1070 score  20.0
# Episode  1071 score  25.0
# Episode  1072 score  11.0
# Episode  1073 score  31.0
# Episode  1074 score  17.0
# Episode  1075 score  16.0
# Episode  1076 score  26.0
# Episode  1077 score  11.0
# Episode  1078 score  14.0
# Episode  1079 score  12.0
# Episode  1080 score  20.0
# Episode  1081 score  19.0
# Episode  1082 score  15.0
# Episode  1083 score  38.0
# Episode  1084 score  14.0
# Episode  1085 score  12.0
# Episode  1086 score  19.0
# Episode  1087 score  48.0
# Episode  1088 score  11.0
# Episode  1089 score  33.0
# Episode  1090 score  27.0
# Episode  1091 score  16.0
# Episode  1092 score  12.0
# Episode  1093 score  12.0
# Episode  1094 score  14.0
# Episode  1095 score  23.0
# Episode  1096 score  17.0
# Episode  1097 score  12.0
# Episode  1098 score  14.0
# Episode  1099 score  18.0
# Episode  1100 score  43.0
# Episode  1101 score  20.0
# Episode  1102 score  18.0
# Episode  1103 score  11.0
# Episode  1104 score  30.0
# Episode  1105 score  32.0
# Episode  1106 score  14.0
# Episode  1107 score  59.0
# Episode  1108 score  17.0
# Episode  1109 score  25.0
# Episode  1110 score  13.0
# Episode  1111 score  14.0
# Episode  1112 score  17.0
# Episode  1113 score  16.0
# Episode  1114 score  17.0
# Episode  1115 score  24.0
# Episode  1116 score  17.0
# Episode  1117 score  20.0
# Episode  1118 score  9.0
# Episode  1119 score  18.0
# Episode  1120 score  12.0
# Episode  1121 score  13.0
# Episode  1122 score  12.0
# Episode  1123 score  18.0
# Episode  1124 score  19.0
# Episode  1125 score  11.0
# Episode  1126 score  13.0
# Episode  1127 score  17.0
# Episode  1128 score  24.0
# Episode  1129 score  14.0
# Episode  1130 score  10.0
# Episode  1131 score  15.0
# Episode  1132 score  52.0
# Episode  1133 score  16.0
# Episode  1134 score  21.0
# Episode  1135 score  9.0
# Episode  1136 score  12.0
# Episode  1137 score  38.0
# Episode  1138 score  15.0
# Episode  1139 score  18.0
# Episode  1140 score  27.0
# Episode  1141 score  24.0
# Episode  1142 score  12.0
# Episode  1143 score  24.0
# Episode  1144 score  19.0
# Episode  1145 score  21.0
# Episode  1146 score  14.0
# Episode  1147 score  14.0
# Episode  1148 score  14.0
# Episode  1149 score  23.0
# Episode  1150 score  16.0
# Episode  1151 score  13.0
# Episode  1152 score  13.0
# Episode  1153 score  27.0
# Episode  1154 score  14.0
# Episode  1155 score  19.0
# Episode  1156 score  10.0
# Episode  1157 score  25.0
# Episode  1158 score  11.0
# Episode  1159 score  32.0
# Episode  1160 score  26.0
# Episode  1161 score  23.0
# Episode  1162 score  22.0
# Episode  1163 score  19.0
# Episode  1164 score  13.0
# Episode  1165 score  13.0
# Episode  1166 score  38.0
# Episode  1167 score  32.0
# Episode  1168 score  16.0
# Episode  1169 score  10.0
# Episode  1170 score  46.0
# Episode  1171 score  11.0
# Episode  1172 score  18.0
# Episode  1173 score  19.0
# Episode  1174 score  18.0
# Episode  1175 score  9.0
# Episode  1176 score  38.0
# Episode  1177 score  34.0
# Episode  1178 score  11.0
# Episode  1179 score  12.0
# Episode  1180 score  13.0
# Episode  1181 score  27.0
# Episode  1182 score  29.0
# Episode  1183 score  11.0
# Episode  1184 score  13.0
# Episode  1185 score  17.0
# Episode  1186 score  21.0
# Episode  1187 score  14.0
# Episode  1188 score  18.0
# Episode  1189 score  27.0
# Episode  1190 score  23.0
# Episode  1191 score  14.0
# Episode  1192 score  40.0
# Episode  1193 score  13.0
# Episode  1194 score  11.0
# Episode  1195 score  12.0
# Episode  1196 score  16.0
# Episode  1197 score  17.0
# Episode  1198 score  46.0
# Episode  1199 score  33.0
# Episode  1200 score  17.0
# Episode  1201 score  30.0
# Episode  1202 score  15.0
# Episode  1203 score  13.0
# Episode  1204 score  17.0
# Episode  1205 score  16.0
# Episode  1206 score  14.0
# Episode  1207 score  13.0
# Episode  1208 score  23.0
# Episode  1209 score  13.0
# Episode  1210 score  9.0
# Episode  1211 score  13.0
# Episode  1212 score  20.0
# Episode  1213 score  11.0
# Episode  1214 score  13.0
# Episode  1215 score  10.0
# Episode  1216 score  12.0
# Episode  1217 score  15.0
# Episode  1218 score  19.0
# Episode  1219 score  19.0
# Episode  1220 score  17.0
# Episode  1221 score  12.0
# Episode  1222 score  22.0
# Episode  1223 score  26.0
# Episode  1224 score  33.0
# Episode  1225 score  19.0
# Episode  1226 score  20.0
# Episode  1227 score  12.0
# Episode  1228 score  35.0
# Episode  1229 score  17.0
# Episode  1230 score  10.0
# Episode  1231 score  37.0
# Episode  1232 score  14.0
# Episode  1233 score  12.0
# Episode  1234 score  13.0
# Episode  1235 score  8.0
# Episode  1236 score  18.0
# Episode  1237 score  33.0
# Episode  1238 score  13.0
# Episode  1239 score  25.0
# Episode  1240 score  14.0
# Episode  1241 score  33.0
# Episode  1242 score  24.0
# Episode  1243 score  47.0
# Episode  1244 score  30.0
# Episode  1245 score  17.0
# Episode  1246 score  25.0
# Episode  1247 score  13.0
# Episode  1248 score  13.0
# Episode  1249 score  11.0
# Episode  1250 score  17.0
# Episode  1251 score  13.0
# Episode  1252 score  19.0
# Episode  1253 score  11.0

# %% [markdown]
# If this works, I should feel good. I very quickly was able to adjust an architecture on the fly in order to switch from a continuous to discrete action space!

# %% [markdown]
# So why doesn't this win? It only ever learns to minimize the negative reward.
#
#
# It learns quite hilariously, that if it stays at the bottom, the negative reward is minimized!
#
# This is just one example of why AC and RL in general is a shaky tool!
